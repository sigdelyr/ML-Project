# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime

# %%
import json
import urllib.request

# QUERY_URL = "https://www.alphavantage.co/query?function={REQUEST_TYPE}&apikey={KEY}&symbol={SYMBOL}&outputsize=full"
API_KEY = "GDFMG7QXIZS4308T"

def _request(symbol, req_type):
    with urllib.request.urlopen(QUERY_URL.format(REQUEST_TYPE=req_type, KEY=API_KEY, SYMBOL=symbol)) as req:
        data = req.read().decode("UTF-8")
    return data

def get_daily_data(symbol):
    return json.loads(_request(symbol, 'TIME_SERIES_DAILY'))

# %%
json_data = get_daily_data('AAPL')

# %%
json_data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (Daily)'])

# %%
apple = pd.DataFrame(json_data['Time Series (Daily)']).T
apple.head()
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2020-01-08  297.1600  304.4399  297.1560  303.1900  32669876
# 2020-01-07  299.8400  300.9000  297.4800  298.3900  27877655
# 2020-01-06  293.7900  299.9600  292.7500  299.8000  29644644
# 2020-01-03  297.1500  300.5800  296.5000  297.4300  36633878
# 2020-01-02  296.2400  300.6000  295.1900  300.3500  33911864

# %%
apple.rename_axis("date", axis='index', inplace=True)

# %%
apple_df = apple.rename(columns={'1. open':'open', '2. high': 'high', '3. low': 'low', '4. close': 'close', '5. volume': 'volume'})
apple_df.head()
# Out:
#                 open      high       low     close    volume
# date
# 2020-01-08  297.1600  304.4399  297.1560  303.1900  32669876
# 2020-01-07  299.8400  300.9000  297.4800  298.3900  27877655
# 2020-01-06  293.7900  299.9600  292.7500  299.8000  29644644
# 2020-01-03  297.1500  300.5800  296.5000  297.4300  36633878
# 2020-01-02  296.2400  300.6000  295.1900  300.3500  33911864

# %%
apple_df.reset_index('date', inplace = True)

# %%
apple_df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume'], dtype='object')

# %%
apple_df['date'] = pd.to_datetime(apple_df['date'])
apple_data = apple_df[apple_df['date'] > '2016-12-31']

# %%
apple_data.tail()
# Out:
#           date      open      high       low     close    volume
# 754 2017-01-09  117.9500  119.4300  117.9400  118.9900  33561948
# 755 2017-01-06  116.7800  118.1600  116.4700  117.9100  31751900
# 756 2017-01-05  115.9200  116.8642  115.8100  116.6100  22193587
# 757 2017-01-04  115.8500  116.5100  115.7500  116.0200  21118116
# 758 2017-01-03  115.8000  116.3300  114.7600  116.1500  28781865

# %%
apple_data = apple_data.rename(columns={"date": "Date",
                               "open": "Open",
                               "high": "High",
                               "low": "Low",
                               "close": "Close",
                               "volume": "Volume"})

# %%
apple_data['Year'] = apple_data['Date'].dt.year
apple_data['Quarter'] = apple_data['Date'].dt.quarter
apple_data
# Out:
#           Date      Open      High       Low     Close     Volume  Year  \
